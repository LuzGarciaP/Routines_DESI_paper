# %%
from astropy.io import fits
import numpy as np
import matplotlib.pyplot as plt
import scipy as sp
import seaborn as sns
 
sns.set_style("white")

plt.rc("font", **{"family": "serif", "serif": ["Computer Modern"]})
plt.rc("text", usetex=True)

# %%
z_tr_l_ar = np.genfromtxt('z_tr_l_ar.txt')
z_rr_l_ar = np.genfromtxt('z_rr_l_ar.txt')
z_rr_b_ar = np.genfromtxt('z_rr_b_ar.txt')

g_xlim2 = [1.5, 4.5]
g_ylim2 = [0,1800]
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(1, 1, 1)
g_fontsize_xyticklabels = 20
ax.tick_params(labelsize=g_fontsize_xyticklabels)
ax.set_xlim(g_xlim2)
ax.set_ylim(g_ylim2)
ax.set_xlabel('$z$', fontsize=25)
ax.set_ylabel('Number of systems', fontsize=25)
plt.hist(z_tr_l_ar, bins=70, edgecolor= 'black', linestyle= '-',align='mid', range=(0,5), fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(z_rr_l_ar, bins=70, linestyle= '--',edgecolor= 'red', align='mid',range=(0,5), fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(z_rr_b_ar, bins=70, linestyle= '--', edgecolor= 'blue', align='mid', range=(0,5), fc='none',histtype='step',linewidth=3, zorder=1)

legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), linewidth=3, linestyle= '-', color='black'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), linewidth=3, linestyle= '--', color='red'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), linewidth=3, linestyle= '--', color='blue'))
legend_labels.append('$z_{tr;noBAL}$')
legend_labels.append('$z_{rr;noBAL}$')
legend_labels.append('$z_{rr;BAL}$')
ax.legend(legend_lines, legend_labels, loc="best", numpoints=1, ncol=1, fontsize=23, handlelength=2.5, frameon=False)
plt.savefig("new_plot.pdf")

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes

diff_bal = np.genfromtxt('diff_bal.txt')
diff_mas = np.genfromtxt('diff_mas.txt')

"""
g_xlim2 = [-0.01, 0.01]
g_ylim2 = [9,1100000]
fig = plt.figure(figsize=(8, 6))
ax = fig.add_subplot(1, 1, 1)
ax.set_yscale('log')
ax.set_xlim(g_xlim2)
ax.set_ylim(g_ylim2)
#plt.tick_params(axis="x", labelsize=20)
#plt.tick_params(axis="y", labelsize=20)
ax.tick_params(labelsize=g_fontsize_xyticklabels)
ax.set_xlabel("$z_{rr}-z_{rr, Lya}$", fontsize=17)
ax.set_ylabel('Number of systems', fontsize=17)
plt.hist(diff_bal, bins=95, edgecolor='red', range=(-0.04,0.04), align='mid', fc='none',histtype='step',linewidth=2, zorder=1)
plt.hist(diff_mas, bins=95, edgecolor='blue', range=(-0.04,0.04), align='mid', fc='none',histtype='step',linewidth=2, zorder=1)
ax.plot([0., 0.], [0., 110000000], 'k:')
#ax.text(-0.008, 90000, 'AI$_{CIV} >$ 0', fontsize=16)
# Setup legend.

legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), linewidth=2, color='red'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), linewidth=2, color='blue'))
legend_labels.append("BAL-QSOs vs. Lya only")
legend_labels.append("Masked BALs vs. Lya only")
ax.legend(legend_lines, legend_labels, loc="best", numpoints=1, ncol=1, fontsize=g_fontsize_legend, handlelength=2.5, frameon=True)
plt.savefig("masked_vs_non_masked_histogram_zrr_all.pdf")
"""

g_xlim2 = [-0.04, 0.04]
g_ylim2 = [0.5,1010000]
fig = plt.figure(figsize=(17, 13))
ax = fig.add_subplot(1, 1, 1)
ax.set_yscale('log')
#ax.set_xlim(g_xlim2)
ax.set_ylim(g_ylim2)
g_fontsize_xyticklabels = 20
ax.tick_params(labelsize=g_fontsize_xyticklabels)
ax.set_xlabel("$z_{rr}-z_{rr;noBAL}$", fontsize=32)
ax.set_ylabel('Number of systems', fontsize=25)
plt.hist(diff_bal, bins=95, edgecolor='red', range=(-0.04,0.04), align='mid',fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(diff_mas, bins=95, edgecolor='blue', range=(-0.04,0.04), align='mid', fc='none',histtype='step',linewidth=3, zorder=1)
ax.plot([0., 0.], [0., 120000000], 'k:')
ax.text(-0.029, 10000, 'AI$_{CIV} >$ 0', fontsize=30)
"""
inset_axes = inset_axes(ax, 
                    width="40%", # width = 30% of parent_bbox
                    height=4.0, # height : 1 inch
                    loc=1)
plt.xlim([-0.01, 0.01])
plt.ylim([9,1100000])
plt.yscale('log')
plt.xticks(fontsize=12)
plt.yticks(fontsize=20)
plt.hist(diff_bal, bins=95, edgecolor='red', range=(-0.04,0.04), align='mid', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(diff_mas, bins=95, edgecolor='blue', range=(-0.04,0.04), align='mid', fc='none',histtype='step',linewidth=3, zorder=1)
plt.plot([0., 0.], [0., 110000000], 'k:')
"""

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), linewidth=3, color='red'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), linewidth=3, color='blue'))
legend_labels.append("BAL-QSOs vs. no-BALs")
legend_labels.append("Masked BALs vs. no-BALs")
ax.legend(legend_lines, legend_labels, loc="upper left", numpoints=1, ncol=1, fontsize=23, handlelength=2.5, frameon=False)
plt.savefig("masked_vs_non_masked_histogram_zrr_all_range.pdf")

# %%
import random
from mpl_toolkits.axes_grid1.inset_locator import inset_axes
wq = 0.002
w = 0.25

zrr_lya_ar_ind_exp_1 = np.genfromtxt('zrr_lya_ar_ind_exp_1.txt')
zrr_lya_ar_ind_exp_2 = np.genfromtxt('zrr_lya_ar_ind_exp_2.txt')
zrr_lya_ar_ind_exp_3 = np.genfromtxt('zrr_lya_ar_ind_exp_3.txt')
zrr_lya_ar_ind_exp_4 = np.genfromtxt('zrr_lya_ar_ind_exp_4.txt')

zrr_bal_ar_ind_exp_1 = np.genfromtxt('zrr_bal_ar_ind_exp_1.txt')
zrr_bal_ar_ind_exp_2 = np.genfromtxt('zrr_bal_ar_ind_exp_2.txt')
zrr_bal_ar_ind_exp_3 = np.genfromtxt('zrr_bal_ar_ind_exp_3.txt')
zrr_bal_ar_ind_exp_4 = np.genfromtxt('zrr_bal_ar_ind_exp_4.txt')

zrr_mas_ar_ind_exp_1 = np.genfromtxt('zrr_mas_ar_ind_exp_1.txt')
zrr_mas_ar_ind_exp_2 = np.genfromtxt('zrr_mas_ar_ind_exp_2.txt')
zrr_mas_ar_ind_exp_3 = np.genfromtxt('zrr_mas_ar_ind_exp_3.txt')
zrr_mas_ar_ind_exp_4 = np.genfromtxt('zrr_mas_ar_ind_exp_4.txt')

print(len(zrr_lya_ar_ind_exp_1[np.where(zrr_lya_ar_ind_exp_1>2.1)]),len(zrr_bal_ar_ind_exp_1[np.where(zrr_lya_ar_ind_exp_1>2.1)]),len(zrr_mas_ar_ind_exp_1[np.where(zrr_lya_ar_ind_exp_1>2.1)]))
print(len(zrr_lya_ar_ind_exp_2[np.where(zrr_lya_ar_ind_exp_2>2.1)]),len(zrr_bal_ar_ind_exp_2[np.where(zrr_lya_ar_ind_exp_2>2.1)]),len(zrr_mas_ar_ind_exp_2[np.where(zrr_lya_ar_ind_exp_2>2.1)]))
print(len(zrr_lya_ar_ind_exp_3[np.where(zrr_lya_ar_ind_exp_3>2.1)]),len(zrr_bal_ar_ind_exp_3[np.where(zrr_lya_ar_ind_exp_3>2.1)]),len(zrr_mas_ar_ind_exp_3[np.where(zrr_lya_ar_ind_exp_3>2.1)]))
print(len(zrr_lya_ar_ind_exp_4[np.where(zrr_lya_ar_ind_exp_4>2.1)]),len(zrr_bal_ar_ind_exp_4[np.where(zrr_lya_ar_ind_exp_4>2.1)]),len(zrr_mas_ar_ind_exp_4[np.where(zrr_lya_ar_ind_exp_4>2.1)]))


arr_lya_1 = zrr_lya_ar_ind_exp_1[np.where(zrr_lya_ar_ind_exp_1>2.1)]
arr_lya_2 = zrr_lya_ar_ind_exp_2[np.where(zrr_lya_ar_ind_exp_2>2.1)]
arr_lya_3 = zrr_lya_ar_ind_exp_3[np.where(zrr_lya_ar_ind_exp_3>2.1)]
arr_lya_4 = zrr_lya_ar_ind_exp_4[np.where(zrr_lya_ar_ind_exp_4>2.1)]

arr_bal_1 = zrr_bal_ar_ind_exp_1[np.where(zrr_lya_ar_ind_exp_1>2.1)]
arr_bal_2 = zrr_bal_ar_ind_exp_2[np.where(zrr_lya_ar_ind_exp_2>2.1)]
arr_bal_3 = zrr_bal_ar_ind_exp_3[np.where(zrr_lya_ar_ind_exp_3>2.1)]
arr_bal_4 = zrr_bal_ar_ind_exp_4[np.where(zrr_lya_ar_ind_exp_4>2.1)]

arr_mas_1 = zrr_mas_ar_ind_exp_1[np.where(zrr_lya_ar_ind_exp_1>2.1)]
arr_mas_2 = zrr_mas_ar_ind_exp_2[np.where(zrr_lya_ar_ind_exp_2>2.1)]
arr_mas_3 = zrr_mas_ar_ind_exp_3[np.where(zrr_lya_ar_ind_exp_3>2.1)]
arr_mas_4 = zrr_mas_ar_ind_exp_4[np.where(zrr_lya_ar_ind_exp_4>2.1)]

_16_percent_1 = int(0.16*len(arr_lya_1)) 
_16_percent_lya_1 = random.sample(list(arr_lya_1), _16_percent_1) 
_16_percent_bal_1 = random.sample(list(arr_bal_1), _16_percent_1) 
_16_percent_mas_1 = random.sample(list(arr_mas_1), _16_percent_1) 
zrr_lya_exp_1 = np.array(_16_percent_lya_1) 
zrr_bal_exp_1 = np.array(_16_percent_bal_1) 
zrr_mas_exp_1 = np.array(_16_percent_mas_1) 

_16_percent_2 = int(0.16*len(arr_lya_2)) 
_16_percent_lya_2 = random.sample(list(arr_lya_2), _16_percent_2) 
_16_percent_bal_2 = random.sample(list(arr_bal_2), _16_percent_2) 
_16_percent_mas_2 = random.sample(list(arr_mas_2), _16_percent_2) 
zrr_lya_exp_2 = np.array(_16_percent_lya_2) 
zrr_bal_exp_2 = np.array(_16_percent_bal_2) 
zrr_mas_exp_2 = np.array(_16_percent_mas_2) 

_16_percent_3 = int(0.16*len(arr_lya_3)) 
_16_percent_lya_3 = random.sample(list(arr_lya_3), _16_percent_3) 
_16_percent_bal_3 = random.sample(list(arr_bal_3), _16_percent_3) 
_16_percent_mas_3 = random.sample(list(arr_mas_3), _16_percent_3) 
zrr_lya_exp_3 = np.array(_16_percent_lya_3) 
zrr_bal_exp_3 = np.array(_16_percent_bal_3) 
zrr_mas_exp_3 = np.array(_16_percent_mas_3) 

_16_percent_4 = int(0.16*len(arr_lya_4)) 
_16_percent_lya_4 = random.sample(list(arr_lya_4), _16_percent_4) 
_16_percent_bal_4 = random.sample(list(arr_bal_4), _16_percent_4) 
_16_percent_mas_4 = random.sample(list(arr_mas_4), _16_percent_4) 
zrr_lya_exp_4 = np.array(_16_percent_lya_4) 
zrr_bal_exp_4 = np.array(_16_percent_bal_4) 
zrr_mas_exp_4 = np.array(_16_percent_mas_4) 

print(len(zrr_lya_exp_1),len(zrr_bal_exp_1),len(zrr_mas_exp_1))
print(len(zrr_lya_exp_2),len(zrr_bal_exp_2),len(zrr_mas_exp_2))
print(len(zrr_lya_exp_3),len(zrr_bal_exp_3),len(zrr_mas_exp_3))
print(len(zrr_lya_exp_4),len(zrr_bal_exp_4),len(zrr_mas_exp_4))


g_xlabel_1 = "$z_{rr}-z_{rr;noBAL}$"
g_ylabel_1 = "Number of systems"

fig1 = plt.figure(figsize=(17, 13))
ax = fig1.add_subplot(1, 1, 1)
g_ylim_2 = [0.5, 1400]
#ax.set_yscale('log')
ax.set_ylim(g_ylim_2)
g_fontsize_xyticklabels = 20
ax.tick_params(labelsize=g_fontsize_xyticklabels)
ax.set_xlabel("$z_{rr}-z_{rr;noBAL}$", fontsize=32)
ax.set_ylabel('Number of systems', fontsize=32)
plt.hist(zrr_bal_exp_1-zrr_lya_exp_1, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='grey', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_bal_exp_2-zrr_lya_exp_2, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='magenta', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_bal_exp_3-zrr_lya_exp_3, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='blue', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_bal_exp_4-zrr_lya_exp_4, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='red', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_1-zrr_lya_exp_1, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='grey', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_2-zrr_lya_exp_2, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='magenta', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_3-zrr_lya_exp_3, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='blue', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_4-zrr_lya_exp_4, bins=np.arange(-3.015, 3.015 + w, w), edgecolor='red', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
ax.text(1.7, 1200, 'AI$_{CIV} >$ 0', fontsize=33)
ax.text(1.7, 1100, '$z_{rr;noBAL} >$ 2.1', fontsize=33)


"""
inset_axes = inset_axes(ax, 
                    width="40%", # width = 30% of parent_bbox
                    height=4.0, # height : 1 inch
                    loc=1)
plt.xlim([-0.02, 0.02])
plt.ylim([0.5, 30])
#plt.yscale('log')
plt.xticks(fontsize=14)
plt.yticks(fontsize=20)
plt.hist(zrr_bal_exp_1-zrr_lya_exp_1, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='grey', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_bal_exp_2-zrr_lya_exp_2, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='magenta', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_bal_exp_3-zrr_lya_exp_3, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='blue', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_bal_exp_4-zrr_lya_exp_4, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='red', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_1-zrr_lya_exp_1, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='grey', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_2-zrr_lya_exp_2, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='magenta', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_3-zrr_lya_exp_3, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='blue', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
plt.hist(zrr_mas_exp_4-zrr_lya_exp_4, bins=np.arange(-0.02,0.02 + wq, wq), edgecolor='red', linestyle='--', fc='none',histtype='step',linewidth=3, zorder=1)
"""
# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='grey', linestyle='-', linewidth=3, markeredgecolor='grey'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='blue', linestyle='-', linewidth=3, markeredgecolor='blue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='red', linestyle='-', linewidth=3, markeredgecolor='red'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='black', linestyle='-', linewidth=3, markeredgecolor='black'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='black', linestyle='--', linewidth=3, markeredgecolor='black'))
legend_labels.append("Exp. time $=$ 1000 s")
legend_labels.append("Exp. time $=$ 2000 s")
legend_labels.append("Exp. time $=$ 3000 s")
legend_labels.append("Exp. time $=$ 4000 s")
legend_labels.append("BAL-QSOs vs. no-BALs")
legend_labels.append("Masked BALs vs. no-BALs")
ax.legend(legend_lines, legend_labels, loc="upper left", numpoints=1, fontsize=25, ncol=1, handlelength=2, frameon=False)

plt.savefig("exptime_zrr_min_ztr_bal_mas_all_range.pdf")
# Out:
# 33220 33220 33220
# 16843 16843 16843
# 11321 11321 11321
# 13647 13647 13647
# 5315 5315 5315
# 2694 2694 2694
# 1811 1811 1811
# 2183 2183 2183

# %%
zrr_bal_fail = np.genfromtxt('zrr_bal_fail.txt')
zrr_bal_miss = np.genfromtxt('zrr_bal_miss.txt')
zrr_bal_lost = np.genfromtxt('zrr_bal_lost.txt')
zrr_mas_fail = np.genfromtxt('zrr_mas_fail.txt')
zrr_mas_miss = np.genfromtxt('zrr_mas_miss.txt')
zrr_mas_lost = np.genfromtxt('zrr_mas_lost.txt')


fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

g_fontsize_legend = 15
g_fontsize_xlabel = 30
g_fontsize_ylabel = 25

g_xlim_9 = [0, 5]
g_ylim_9 = [0, 600]
g_xlabel_9 = "$z_{rr}$"
g_ylabel_9 = "Number of systems"

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 380, 'BAL-QSOs', fontsize=25)

plt.hist(zrr_bal_fail, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_bal_miss, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
plt.hist(zrr_bal_lost, bins=20, edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_bal_zrr.pdf")

fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 380, 'Masked BALs', fontsize=25)

plt.hist(zrr_mas_fail, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_mas_miss, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
plt.hist(zrr_mas_lost, bins=20, edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_mas_zrr.pdf")

# %%
# Bad fits exp = 1000 s

zrr_bal_fail1 = np.genfromtxt('zrr_bal_fail_1.txt')
zrr_bal_miss1 = np.genfromtxt('zrr_bal_miss_1.txt')
zrr_bal_lost1 = np.genfromtxt('zrr_bal_lost_1.txt')
zrr_mas_fail1 = np.genfromtxt('zrr_mas_fail_1.txt')
zrr_mas_miss1 = np.genfromtxt('zrr_mas_miss_1.txt')
zrr_mas_lost1 = np.genfromtxt('zrr_mas_lost_1.txt')


fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

g_fontsize_legend = 15
g_fontsize_xlabel = 30
g_fontsize_ylabel = 25

g_xlim_9 = [0, 5]
g_ylim_9 = [0, 600]
g_xlabel_9 = "$z_{rr}$"
g_ylabel_9 = "Number of systems"

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 380, 'BAL-QSOs', fontsize=25)
ax9.text(3.5, 320, 'Exp time $=$ 1000 s', fontsize=25)

plt.hist(zrr_bal_fail1, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_bal_miss1, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
plt.hist(zrr_bal_lost1, bins=20, edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_bal_zrr_1.pdf")

fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 380, 'Masked BALs', fontsize=25)

plt.hist(zrr_mas_fail1, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_mas_miss1, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
plt.hist(zrr_mas_lost1, bins=np.arange(min(zrr_mas_lost1), max(zrr_mas_lost1) + 0.08, 0.08), edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_mas_zrr_1.pdf")

# %%
# Bad fits exp = 2000 s

zrr_bal_fail2 = np.genfromtxt('zrr_bal_fail_2.txt')
zrr_bal_miss2 = np.genfromtxt('zrr_bal_miss_2.txt')
zrr_bal_lost2 = np.genfromtxt('zrr_bal_lost_2.txt')
zrr_mas_fail2 = np.genfromtxt('zrr_mas_fail_2.txt')
zrr_mas_miss2 = np.genfromtxt('zrr_mas_miss_2.txt')
#zrr_mas_lost2 = np.genfromtxt('zrr_mas_lost_2.txt')

fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

g_fontsize_legend = 15
g_fontsize_xlabel = 30
g_fontsize_ylabel = 25

g_xlim_9 = [0, 5]
g_ylim_9 = [0, 45]
g_xlabel_9 = "$z_{rr}$"
g_ylabel_9 = "Number of systems"

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 25, 'BAL-QSOs', fontsize=25)
ax9.text(3.5, 21, 'Exp time $=$ 2000 s', fontsize=25)

plt.hist(zrr_bal_fail2, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_bal_miss2, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
plt.hist(zrr_bal_lost2, bins=np.arange(min(zrr_bal_lost2), max(zrr_bal_lost2) + 0.08, 0.08), edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_bal_zrr_2.pdf")

fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 25, 'Masked BALs', fontsize=25)

plt.hist(zrr_mas_fail2, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_mas_miss2, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
#plt.hist(zrr_mas_lost2, bins=20, edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_mas_zrr_2.pdf")

# %%
# Bad fits exp = 3000 s

zrr_bal_fail3 = np.genfromtxt('zrr_bal_fail_3.txt')
zrr_bal_miss3 = np.genfromtxt('zrr_bal_miss_3.txt')
zrr_bal_lost3 = np.genfromtxt('zrr_bal_lost_3.txt')
zrr_mas_fail3 = np.genfromtxt('zrr_mas_fail_3.txt')
zrr_mas_miss3 = np.genfromtxt('zrr_mas_miss_3.txt')
#zrr_mas_lost3 = np.genfromtxt('zrr_mas_lost_3.txt')


fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

g_fontsize_legend = 15
g_fontsize_xlabel = 30
g_fontsize_ylabel = 25

g_xlim_9 = [0, 5]
g_ylim_9 = [0, 16]
g_xlabel_9 = "$z_{rr}$"
g_ylabel_9 = "Number of systems"

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 10, 'BAL-QSOs', fontsize=25)
ax9.text(3.5, 8, 'Exp time $=$ 3000 s', fontsize=25)

plt.hist(zrr_bal_fail3, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_bal_miss3, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
plt.hist(zrr_bal_lost3, bins=np.arange(min(zrr_bal_lost3), max(zrr_bal_lost3) + 0.08, 0.08), edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="upper right", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_bal_zrr_3.pdf")

fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 10, 'Masked BALs', fontsize=25)

plt.hist(zrr_mas_fail3, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_mas_miss3, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
#plt.hist(zrr_mas_lost3, bins=20, edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_mas_zrr_3.pdf")

# %%
# Bad fits exp = 4000 s

zrr_bal_fail4 = np.genfromtxt('zrr_bal_fail_4.txt')
zrr_bal_miss4 = np.genfromtxt('zrr_bal_miss_4.txt')
zrr_bal_lost4 = np.genfromtxt('zrr_bal_lost_4.txt')
zrr_mas_fail4 = np.genfromtxt('zrr_mas_fail_4.txt')
zrr_mas_miss4 = np.genfromtxt('zrr_mas_miss_4.txt')
#zrr_mas_lost4 = np.genfromtxt('zrr_mas_lost_4.txt')


fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

g_fontsize_legend = 15
g_fontsize_xlabel = 30
g_fontsize_ylabel = 25

g_xlim_9 = [0, 5]
g_ylim_9 = [0, 20]
g_xlabel_9 = "$z_{rr}$"
g_ylabel_9 = "Number of systems"

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 12, 'BAL-QSOs', fontsize=25)
ax9.text(3.5, 10, 'Exp time $=$ 4000 s', fontsize=25)

plt.hist(zrr_bal_fail4, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_bal_miss4, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
plt.hist(zrr_bal_lost4, bins=np.arange(min(zrr_bal_lost4), max(zrr_bal_lost4) + 0.09, 0.09), edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_bal_zrr_4.pdf")

fig9 = plt.figure(figsize=(12, 8))
ax9 = fig9.add_subplot(1, 1, 1)

ax9.set_xlim(g_xlim_9)
ax9.set_ylim(g_ylim_9)
g_fontsize_xyticklabels = 20
ax9.tick_params(labelsize=g_fontsize_xyticklabels)
ax9.set_xlabel(g_xlabel_9, fontsize=g_fontsize_xlabel)
ax9.set_ylabel(g_ylabel_9, fontsize=g_fontsize_ylabel)
ax9.text(3.5, 12, 'Masked BALs', fontsize=25)

plt.hist(zrr_mas_fail4, bins=20, edgecolor='darkblue',density = False, fc='none',histtype='step',linewidth=3, linestyle='-', zorder=10)
plt.hist(zrr_mas_miss4, bins=20, edgecolor='magenta', density = False, fc='none',histtype='step',linewidth=3,zorder=2)
#plt.hist(zrr_mas_lost4, bins=20, edgecolor='cyan', density = False, fc='none',histtype='step',linewidth=3,zorder=3)

# Setup legend.
legend_lines = []
legend_labels = []
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='darkblue', linestyle='-', linewidth=3, markeredgecolor='darkblue'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='magenta', linestyle='-', linewidth=3, markeredgecolor='magenta'))
legend_lines.append(plt.Line2D((0, 0), (0, 0), color='cyan', linestyle='-', linewidth=3, markeredgecolor='cyan'))
legend_labels.append("Failed")
legend_labels.append("Missed")
legend_labels.append("Lost")
ax9.legend(legend_lines, legend_labels, loc="best", numpoints=1, fontsize=23, ncol=1, handlelength=2.5, frameon=False)

plt.savefig("redshift_dist_wrong_fits_mas_zrr_4.pdf")
